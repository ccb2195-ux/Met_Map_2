# %% [markdown]
# # Exploring the Credit line
# ## Looking at who gave the most art to the MET and perhaps where it came from geographically

# %%
df['Credit Line'].value_counts().head(20)

# %%
df['Year'] = df['Credit Line'].str.extract(r'(\d{4})')
df['Year'] = pd.to_numeric(df['Year'])
